# %% [markdown]
# ![fcc_logo.jpg](attachment:fcc_logo.jpg)

# %% [markdown]
# ## Section 6: Data Visualisations with Python and Tableau - HOMEWORK
#
# - No specific homework in this section, but we strongly encourage you at this point to read/play around visualisations covered in lessons
# - You should be comfortable making a variety of graphs and interpret them - fill in the gaps if you have any!
